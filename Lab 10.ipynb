# %% [markdown]
# # Lab 10: The Zeeman Effect
#
# Shreya Parjan
# & Alex G.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import scipy.optimize
import math as m
#%matplotlib inline
# %matplotlib notebook

# %%
data = np.loadtxt('4046wfield.dat',delimiter = ',')
data2 = np.loadtxt('4358wfield.dat',delimiter = ',')

c = data[:,1] #counts
l = data[:,0] #wavelengths A

c2 = data2[:,1] #counts
l2 = data2[:,0] #wavelengths A


plt.figure()
plt.plot(l, c, 'bo') #without '-' after bo, plots points alone
plt.xlabel('Wavelength (A)') # label the x-axis
plt.ylabel('Counts', size=12) # label the y-axis
plt.title('Counts vs Wavelength at 4046.6 A (with field)') # title
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
plt.figure()
plt.plot(l2, c2, 'bo') #without '-' after bo, plots points alone
plt.xlabel('Wavelength (A)') # label the x-axis
plt.ylabel('Counts', size=12) # label the y-axis
plt.title('Counts vs Wavelength at 4358 A (with field)') # title
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
#for 4046
hc = 12400 #eV/A
l = 4046.6 #A
lmax = 8092.44/2 #A
lmin = 8090.96/2 #A
deltal = (lmax-lmin)/2
#print(deltal)
deltaE = (hc*deltal)/(l**2)
#print(deltaE)

mj = 1
g = 2
muB = 5.7884e-5 #ev/T
B0 = deltaE/(mj*g*muB)
print("B0 = ",B0)
# Out:
# B0 =  2.420217095640541

# %%
#for 4358
l2 = 4358.4

lmaxin = 8715.57/2
lminin = 8715.13/2
deltalin = (lmaxin-lminin)/2
deltaein = (hc*deltalin)/(l2**2)

lmaxmid = 8716.01/2
lminmid = 8714.74/2
deltalmid = (lmaxmid-lminmid)/2
deltaemid = (hc*deltalmid)/(l2**2)

lmaxout = 8716.22/2
lminout = 8714.51/2
deltalout = (lmaxout-lminout)/2
deltaeout = (hc*deltalout)/(l2**2)
print("Changes in Energy (in, mid, out) = ")
print(deltaein)
print(deltaemid)
print(deltaeout)

gIn = deltaein/(mj*muB*B0)
gMid = deltaemid/(mj*muB*B0)
gOut = deltaeout/(mj*muB*B0)
print("g values (in 1/2, mid 3/2, out 5/2) = ")
print(gIn)
print(gMid)
print(gOut)
# Out:
# Changes in Energy (in, mid, out) =
# 7.180591134234779e-05
# 0.00020725797137433516
# 0.00027906388271638606
# g values (in, mid, out) =
# 0.5125631020362568
# 1.4794434990579917
# 1.9920066010921293

# %%
sigdeltaL = 0.01
sigdeltaE = hc*sigdeltaL/(l**2)
sigB0 = sigdeltaE/(mj*g*muB)
print("uncertainty in magnetic field = ",sigB0)
# Out:
# uncertainty in magnetic field =  0.06541127285516904

# %% [markdown]
# 1. The uncertainty in B0 is 0.07T which is consistent with the measured value of 2.42T
# 2. We did not do polarization.
# 3. See above
# 4. According to the selection rules, the change in the magnetic quantum number is at most +/-1. At a wavelength of 4358.4 A, we won't see the lines from -1 to +1, +1 to -1, and we also won't see the line from 0 to 0 since it has a short lifetime and there is a rule that you won't see the 0 to 0 line. For the same wavelength, we saw the lines from -1 to 0, -1 to -1, 0 to 1, 0 to -1, 1 to 1, and 1 to 0 because they fall within the bounds specified by the selection rules. For 4046.6 A, we saw all of the transitions because they were all within the bounds specified by the selection rules.
